# %% [markdown]
# This notebook contains the source code for the second milestone of the homework for the course  Deep Learning in Practice with Python and LUA by the team Fellow Scholars.
# Our goal is to denoise speech using Deep Learning, our choice of model architecture is a variant of wavenet, called the speech denoising wavenet.
# Our main source was this paper: https://arxiv.org/pdf/1706.07162.pdf
#
# The members of the team are:
# Balázs Glávits
# Márk Konrád
# Andor kiss

# %%
#GPU Check
# !nvidia-smi
# Out:
# Fri Nov 20 12:57:20 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P0    36W / 250W |   5673MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#I import the data from my Google Drive
#We use a dummy dataset, consisting of 800 noisy and 800 clean train samples and 200 noisy and 200 clean validation samples
from google.colab import drive
import numpy as np

drive.mount('/content/drive', force_remount=False)

noisy_train=np.load('/content/drive/My Drive/MLFolder/FellowScholars/noisy_train.npy')
clean_train=np.load('/content/drive/My Drive/MLFolder/FellowScholars/clean_train.npy')
noisy_val=np.load('/content/drive/My Drive/MLFolder/FellowScholars/noisy_val.npy')
clean_val=np.load('/content/drive/My Drive/MLFolder/FellowScholars/clean_val.npy')

#We didn't use our test dataset yet, because our model couldn't provide us with a satisfying validation accuracy.

#noisy_test=np.load('/content/drive/My Drive/MLFolder/FellowScholars/noisy_test.npy')
#clean_test=np.load('/content/drive/My Drive/MLFolder/FellowScholars/clean_test.npy')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (800, 119041, 1)
# (200, 119041, 1)

# %%
#To make the data smaller, so we don't run out of ram, we slice them, and save the slices for our datagenerator.
#This is the slicing cell.
SLICE_SIZE=2048

newnoisy=[]
for file in noisy_train:
  slice_count = int(119041 / SLICE_SIZE)
  for i in range(slice_count):
    noisy_slice = file[i*SLICE_SIZE:(i+1)*SLICE_SIZE, :]
    newnoisy.append(noisy_slice)

newnoisy=np.asarray(newnoisy)


newclean=[]
for file in clean_train:
  slice_count = int(119041 / SLICE_SIZE)
  for i in range(slice_count):
    noisy_slice = file[i*SLICE_SIZE:(i+1)*SLICE_SIZE, :]
    newclean.append(noisy_slice)

newclean=np.asarray(newclean)


newnoisyval=[]
for file in noisy_val:
  slice_count = int(119041 / SLICE_SIZE)
  for i in range(slice_count):
    noisy_slice = file[i*SLICE_SIZE:(i+1)*SLICE_SIZE, :]
    newnoisyval.append(noisy_slice)

newnoisyval=np.asarray(newnoisyval)


newcleanval=[]
for file in clean_val:
  slice_count = int(119041 / SLICE_SIZE)
  for i in range(slice_count):
    noisy_slice = file[i*SLICE_SIZE:(i+1)*SLICE_SIZE, :]
    newcleanval.append(noisy_slice)

newcleanval=np.asarray(newcleanval)

# %%
#Here i make some directories for the saved data.
import os
os.makedirs('train/noisy')
os.mkdir('train/clean')
os.makedirs('val/noisy')
os.mkdir('val/clean')

# %%
#This cell is for data saving

for i, element in enumerate(newnoisy):
  np.save('train/noisy/' + str(i) + '.npy', element)


for i, element in enumerate(newclean):
  np.save('train/clean/' + str(i) + '.npy', element)


for i, element in enumerate(newnoisyval):
  np.save('val/noisy/' + str(i) + '.npy', element)


for i, element in enumerate(newcleanval):
  np.save('val/clean/' + str(i) + '.npy', element)

# %%
#We one-hot encode our sound samples
def onehot_256(value):
    return np.eye(256)[value]

#This is a DataGenerator class, which helps us conserve ram, by prodiving the model the data in batches.
#The code was inspired by this guide: https://stanford.edu/~shervine/blog/keras-how-to-generate-data-on-the-fly
from keras.utils import Sequence
class MyDatagen(Sequence):
  def __init__(self, list_IDs, batch_size=16, dim=(2048, 256), shuffle=True, validation=False):
    'Initialization'
    self.dim = dim
    self.batch_size = batch_size
    self.list_IDs = list_IDs
    self.shuffle = shuffle
    self.validation=validation
    self.on_epoch_end()

  def __len__(self):
    return int(np.floor(len(self.list_IDs) / self.batch_size))

  def __getitem__(self, index):
    # Generate indexes of the batch
    indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

    # Find list of IDs
    list_IDs_temp = [self.list_IDs[k] for k in indexes]

    # Generate data
    X, y = self.__data_generation(list_IDs_temp)

    return X, y

  def on_epoch_end(self):
      #Updates indexes after each epoch
    self.indexes = np.arange(len(self.list_IDs))
    if self.shuffle == True:
      np.random.shuffle(self.indexes)

  def __data_generation(self, list_IDs_temp):
    #Generates data containing batch_size samples
    if self.validation:
      X = np.empty((self.batch_size, *self.dim))
      y = np.empty((self.batch_size, *self.dim))

      # Generate data
      for i, ID in enumerate(list_IDs_temp):
        #We do the one-hot encodings here.
        X[i,] = np.squeeze(onehot_256(np.load('val/noisy/' + str(ID) + '.npy')))

        y[i,] = np.squeeze(onehot_256(np.load('val/clean/' + str(ID) + '.npy')))

      return np.squeeze((X)), np.squeeze((y))
    else:
      X = np.empty((self.batch_size, *self.dim))
      y = np.empty((self.batch_size, *self.dim))

      # Generate data
      for i, ID in enumerate(list_IDs_temp):
        X[i,] = np.squeeze(onehot_256(np.load('train/noisy/' + str(ID) + '.npy')))

        y[i,] = np.squeeze(onehot_256(np.load('train/clean/' + str(ID) + '.npy')))



      return np.squeeze((X)), np.squeeze((y))

# %%
#Some garbage collection if needed
import gc
gc.collect()
# Out:
# 430

# %%
#This is our model, inspired by the speech denoising wavenet paper.
from keras.models import Model
from keras.layers import Conv1D, Conv2D, Flatten, Dense, \
  Input, Activation, Add, Multiply

def wavenet_residual_block(filters, kernel_size, dilation_rate):
  def f(input_):
    conv = Conv1D(filters, kernel_size,
                  dilation_rate=dilation_rate,
                  activation=None,
                  padding='same')(input_)
    tanh_out = Activation('tanh')(conv)
    sigmoid_out = Activation('sigmoid')(conv)
    merged = Multiply()([tanh_out, sigmoid_out])
    skip_out = Conv1D(1, 1, activation='relu',
                      padding='same')(merged)
    out = Add()([skip_out, input_])
    return out, skip_out
  return f

def wavenet_convolutional_layers(filters, kernel_size, depth):
  def f(input_):
    out = input_
    skip_connections = []
    for i in range(1, depth + 1):
        dilation_rate = 2**(i % 9)
        out, skip_out = wavenet_residual_block(filters, kernel_size, dilation_rate)(out)
        skip_connections.append(skip_out)
    sum = Add()(skip_connections)
    act = Activation('relu')(sum)
    return act
  return f

def wavenet(input_size=2048):
  input_ = Input(shape=(input_size, 256))
  net = wavenet_convolutional_layers(64, 2, 30)(input_)
  net = Conv1D(2048, 3, activation='relu', padding='same')(net)
  net = Conv1D(256, 3, padding='same')(net)
  #net = Flatten()(net)
  net = Dense(256, activation='softmax')(net)
  model = Model(input_, net)
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  model.summary()
  return model

# %%
model = wavenet(2048)
# Out:
# Model: "functional_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 2048, 256)]  0
# __________________________________________________________________________________________________
# conv1d_310 (Conv1D)             (None, 2048, 64)     32832       input_7[0][0]
# __________________________________________________________________________________________________
# activation_306 (Activation)     (None, 2048, 64)     0           conv1d_310[0][0]
# __________________________________________________________________________________________________
# activation_307 (Activation)     (None, 2048, 64)     0           conv1d_310[0][0]
# __________________________________________________________________________________________________
# multiply_150 (Multiply)         (None, 2048, 64)     0           activation_306[0][0]
#                                                                  activation_307[0][0]
# __________________________________________________________________________________________________
# conv1d_311 (Conv1D)             (None, 2048, 1)      65          multiply_150[0][0]
# __________________________________________________________________________________________________
# add_156 (Add)                   (None, 2048, 256)    0           conv1d_311[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# conv1d_312 (Conv1D)             (None, 2048, 64)     32832       add_156[0][0]
# __________________________________________________________________________________________________
# activation_308 (Activation)     (None, 2048, 64)     0           conv1d_312[0][0]
# __________________________________________________________________________________________________
# activation_309 (Activation)     (None, 2048, 64)     0           conv1d_312[0][0]
# __________________________________________________________________________________________________
# multiply_151 (Multiply)         (None, 2048, 64)     0           activation_308[0][0]
#                                                                  activation_309[0][0]
# __________________________________________________________________________________________________
# conv1d_313 (Conv1D)             (None, 2048, 1)      65          multiply_151[0][0]
# __________________________________________________________________________________________________
# add_157 (Add)                   (None, 2048, 256)    0           conv1d_313[0][0]
#                                                                  add_156[0][0]
# __________________________________________________________________________________________________
# conv1d_314 (Conv1D)             (None, 2048, 64)     32832       add_157[0][0]
# __________________________________________________________________________________________________
# activation_310 (Activation)     (None, 2048, 64)     0           conv1d_314[0][0]
# __________________________________________________________________________________________________
# activation_311 (Activation)     (None, 2048, 64)     0           conv1d_314[0][0]
# __________________________________________________________________________________________________
# multiply_152 (Multiply)         (None, 2048, 64)     0           activation_310[0][0]
#                                                                  activation_311[0][0]
# __________________________________________________________________________________________________
# conv1d_315 (Conv1D)             (None, 2048, 1)      65          multiply_152[0][0]
# __________________________________________________________________________________________________
# add_158 (Add)                   (None, 2048, 256)    0           conv1d_315[0][0]
#                                                                  add_157[0][0]
# __________________________________________________________________________________________________
# conv1d_316 (Conv1D)             (None, 2048, 64)     32832       add_158[0][0]
# __________________________________________________________________________________________________
# activation_312 (Activation)     (None, 2048, 64)     0           conv1d_316[0][0]
# __________________________________________________________________________________________________
# activation_313 (Activation)     (None, 2048, 64)     0           conv1d_316[0][0]
# __________________________________________________________________________________________________
# multiply_153 (Multiply)         (None, 2048, 64)     0           activation_312[0][0]
#                                                                  activation_313[0][0]
# __________________________________________________________________________________________________
# conv1d_317 (Conv1D)             (None, 2048, 1)      65          multiply_153[0][0]
# __________________________________________________________________________________________________
# add_159 (Add)                   (None, 2048, 256)    0           conv1d_317[0][0]
#                                                                  add_158[0][0]
# __________________________________________________________________________________________________
# conv1d_318 (Conv1D)             (None, 2048, 64)     32832       add_159[0][0]
# __________________________________________________________________________________________________
# activation_314 (Activation)     (None, 2048, 64)     0           conv1d_318[0][0]
# __________________________________________________________________________________________________
# activation_315 (Activation)     (None, 2048, 64)     0           conv1d_318[0][0]
# __________________________________________________________________________________________________
# multiply_154 (Multiply)         (None, 2048, 64)     0           activation_314[0][0]
#                                                                  activation_315[0][0]
# __________________________________________________________________________________________________
# conv1d_319 (Conv1D)             (None, 2048, 1)      65          multiply_154[0][0]
# __________________________________________________________________________________________________
# add_160 (Add)                   (None, 2048, 256)    0           conv1d_319[0][0]
#                                                                  add_159[0][0]
# __________________________________________________________________________________________________
# conv1d_320 (Conv1D)             (None, 2048, 64)     32832       add_160[0][0]
# __________________________________________________________________________________________________
# activation_316 (Activation)     (None, 2048, 64)     0           conv1d_320[0][0]
# __________________________________________________________________________________________________
# activation_317 (Activation)     (None, 2048, 64)     0           conv1d_320[0][0]
# __________________________________________________________________________________________________
# multiply_155 (Multiply)         (None, 2048, 64)     0           activation_316[0][0]
#                                                                  activation_317[0][0]
# __________________________________________________________________________________________________
# conv1d_321 (Conv1D)             (None, 2048, 1)      65          multiply_155[0][0]
# __________________________________________________________________________________________________
# add_161 (Add)                   (None, 2048, 256)    0           conv1d_321[0][0]
#                                                                  add_160[0][0]
# __________________________________________________________________________________________________
# conv1d_322 (Conv1D)             (None, 2048, 64)     32832       add_161[0][0]
# __________________________________________________________________________________________________
# activation_318 (Activation)     (None, 2048, 64)     0           conv1d_322[0][0]
# __________________________________________________________________________________________________
# activation_319 (Activation)     (None, 2048, 64)     0           conv1d_322[0][0]
# __________________________________________________________________________________________________
# multiply_156 (Multiply)         (None, 2048, 64)     0           activation_318[0][0]
#                                                                  activation_319[0][0]
# __________________________________________________________________________________________________
# conv1d_323 (Conv1D)             (None, 2048, 1)      65          multiply_156[0][0]
# __________________________________________________________________________________________________
# add_162 (Add)                   (None, 2048, 256)    0           conv1d_323[0][0]
#                                                                  add_161[0][0]
# __________________________________________________________________________________________________
# conv1d_324 (Conv1D)             (None, 2048, 64)     32832       add_162[0][0]
# __________________________________________________________________________________________________
# activation_320 (Activation)     (None, 2048, 64)     0           conv1d_324[0][0]
# __________________________________________________________________________________________________
# activation_321 (Activation)     (None, 2048, 64)     0           conv1d_324[0][0]
# __________________________________________________________________________________________________
# multiply_157 (Multiply)         (None, 2048, 64)     0           activation_320[0][0]
#                                                                  activation_321[0][0]
# __________________________________________________________________________________________________
# conv1d_325 (Conv1D)             (None, 2048, 1)      65          multiply_157[0][0]
# __________________________________________________________________________________________________
# add_163 (Add)                   (None, 2048, 256)    0           conv1d_325[0][0]
#                                                                  add_162[0][0]
# __________________________________________________________________________________________________
# conv1d_326 (Conv1D)             (None, 2048, 64)     32832       add_163[0][0]
# __________________________________________________________________________________________________
# activation_322 (Activation)     (None, 2048, 64)     0           conv1d_326[0][0]
# __________________________________________________________________________________________________
# activation_323 (Activation)     (None, 2048, 64)     0           conv1d_326[0][0]
# __________________________________________________________________________________________________
# multiply_158 (Multiply)         (None, 2048, 64)     0           activation_322[0][0]
#                                                                  activation_323[0][0]
# __________________________________________________________________________________________________
# conv1d_327 (Conv1D)             (None, 2048, 1)      65          multiply_158[0][0]
# __________________________________________________________________________________________________
# add_164 (Add)                   (None, 2048, 256)    0           conv1d_327[0][0]
#                                                                  add_163[0][0]
# __________________________________________________________________________________________________
# conv1d_328 (Conv1D)             (None, 2048, 64)     32832       add_164[0][0]
# __________________________________________________________________________________________________
# activation_324 (Activation)     (None, 2048, 64)     0           conv1d_328[0][0]
# __________________________________________________________________________________________________
# activation_325 (Activation)     (None, 2048, 64)     0           conv1d_328[0][0]
# __________________________________________________________________________________________________
# multiply_159 (Multiply)         (None, 2048, 64)     0           activation_324[0][0]
#                                                                  activation_325[0][0]
# __________________________________________________________________________________________________
# conv1d_329 (Conv1D)             (None, 2048, 1)      65          multiply_159[0][0]
# __________________________________________________________________________________________________
# add_165 (Add)                   (None, 2048, 256)    0           conv1d_329[0][0]
#                                                                  add_164[0][0]
# __________________________________________________________________________________________________
# conv1d_330 (Conv1D)             (None, 2048, 64)     32832       add_165[0][0]
# __________________________________________________________________________________________________
# activation_326 (Activation)     (None, 2048, 64)     0           conv1d_330[0][0]
# __________________________________________________________________________________________________
# activation_327 (Activation)     (None, 2048, 64)     0           conv1d_330[0][0]
# __________________________________________________________________________________________________
# multiply_160 (Multiply)         (None, 2048, 64)     0           activation_326[0][0]
#                                                                  activation_327[0][0]
# __________________________________________________________________________________________________
# conv1d_331 (Conv1D)             (None, 2048, 1)      65          multiply_160[0][0]
# __________________________________________________________________________________________________
# add_166 (Add)                   (None, 2048, 256)    0           conv1d_331[0][0]
#                                                                  add_165[0][0]
# __________________________________________________________________________________________________
# conv1d_332 (Conv1D)             (None, 2048, 64)     32832       add_166[0][0]
# __________________________________________________________________________________________________
# activation_328 (Activation)     (None, 2048, 64)     0           conv1d_332[0][0]
# __________________________________________________________________________________________________
# activation_329 (Activation)     (None, 2048, 64)     0           conv1d_332[0][0]
# __________________________________________________________________________________________________
# multiply_161 (Multiply)         (None, 2048, 64)     0           activation_328[0][0]
#                                                                  activation_329[0][0]
# __________________________________________________________________________________________________
# conv1d_333 (Conv1D)             (None, 2048, 1)      65          multiply_161[0][0]
# __________________________________________________________________________________________________
# add_167 (Add)                   (None, 2048, 256)    0           conv1d_333[0][0]
#                                                                  add_166[0][0]
# __________________________________________________________________________________________________
# conv1d_334 (Conv1D)             (None, 2048, 64)     32832       add_167[0][0]
# __________________________________________________________________________________________________
# activation_330 (Activation)     (None, 2048, 64)     0           conv1d_334[0][0]
# __________________________________________________________________________________________________
# activation_331 (Activation)     (None, 2048, 64)     0           conv1d_334[0][0]
# __________________________________________________________________________________________________
# multiply_162 (Multiply)         (None, 2048, 64)     0           activation_330[0][0]
#                                                                  activation_331[0][0]
# __________________________________________________________________________________________________
# conv1d_335 (Conv1D)             (None, 2048, 1)      65          multiply_162[0][0]
# __________________________________________________________________________________________________
# add_168 (Add)                   (None, 2048, 256)    0           conv1d_335[0][0]
#                                                                  add_167[0][0]
# __________________________________________________________________________________________________
# conv1d_336 (Conv1D)             (None, 2048, 64)     32832       add_168[0][0]
# __________________________________________________________________________________________________
# activation_332 (Activation)     (None, 2048, 64)     0           conv1d_336[0][0]
# __________________________________________________________________________________________________
# activation_333 (Activation)     (None, 2048, 64)     0           conv1d_336[0][0]
# __________________________________________________________________________________________________
# multiply_163 (Multiply)         (None, 2048, 64)     0           activation_332[0][0]
#                                                                  activation_333[0][0]
# __________________________________________________________________________________________________
# conv1d_337 (Conv1D)             (None, 2048, 1)      65          multiply_163[0][0]
# __________________________________________________________________________________________________
# add_169 (Add)                   (None, 2048, 256)    0           conv1d_337[0][0]
#                                                                  add_168[0][0]
# __________________________________________________________________________________________________
# conv1d_338 (Conv1D)             (None, 2048, 64)     32832       add_169[0][0]
# __________________________________________________________________________________________________
# activation_334 (Activation)     (None, 2048, 64)     0           conv1d_338[0][0]
# __________________________________________________________________________________________________
# activation_335 (Activation)     (None, 2048, 64)     0           conv1d_338[0][0]
# __________________________________________________________________________________________________
# multiply_164 (Multiply)         (None, 2048, 64)     0           activation_334[0][0]
#                                                                  activation_335[0][0]
# __________________________________________________________________________________________________
# conv1d_339 (Conv1D)             (None, 2048, 1)      65          multiply_164[0][0]
# __________________________________________________________________________________________________
# add_170 (Add)                   (None, 2048, 256)    0           conv1d_339[0][0]
#                                                                  add_169[0][0]
# __________________________________________________________________________________________________
# conv1d_340 (Conv1D)             (None, 2048, 64)     32832       add_170[0][0]
# __________________________________________________________________________________________________
# activation_336 (Activation)     (None, 2048, 64)     0           conv1d_340[0][0]
# __________________________________________________________________________________________________
# activation_337 (Activation)     (None, 2048, 64)     0           conv1d_340[0][0]
# __________________________________________________________________________________________________
# multiply_165 (Multiply)         (None, 2048, 64)     0           activation_336[0][0]
#                                                                  activation_337[0][0]
# __________________________________________________________________________________________________
# conv1d_341 (Conv1D)             (None, 2048, 1)      65          multiply_165[0][0]
# __________________________________________________________________________________________________
# add_171 (Add)                   (None, 2048, 256)    0           conv1d_341[0][0]
#                                                                  add_170[0][0]
# __________________________________________________________________________________________________
# conv1d_342 (Conv1D)             (None, 2048, 64)     32832       add_171[0][0]
# __________________________________________________________________________________________________
# activation_338 (Activation)     (None, 2048, 64)     0           conv1d_342[0][0]
# __________________________________________________________________________________________________
# activation_339 (Activation)     (None, 2048, 64)     0           conv1d_342[0][0]
# __________________________________________________________________________________________________
# multiply_166 (Multiply)         (None, 2048, 64)     0           activation_338[0][0]
#                                                                  activation_339[0][0]
# __________________________________________________________________________________________________
# conv1d_343 (Conv1D)             (None, 2048, 1)      65          multiply_166[0][0]
# __________________________________________________________________________________________________
# add_172 (Add)                   (None, 2048, 256)    0           conv1d_343[0][0]
#                                                                  add_171[0][0]
# __________________________________________________________________________________________________
# conv1d_344 (Conv1D)             (None, 2048, 64)     32832       add_172[0][0]
# __________________________________________________________________________________________________
# activation_340 (Activation)     (None, 2048, 64)     0           conv1d_344[0][0]
# __________________________________________________________________________________________________
# activation_341 (Activation)     (None, 2048, 64)     0           conv1d_344[0][0]
# __________________________________________________________________________________________________
# multiply_167 (Multiply)         (None, 2048, 64)     0           activation_340[0][0]
#                                                                  activation_341[0][0]
# __________________________________________________________________________________________________
# conv1d_345 (Conv1D)             (None, 2048, 1)      65          multiply_167[0][0]
# __________________________________________________________________________________________________
# add_173 (Add)                   (None, 2048, 256)    0           conv1d_345[0][0]
#                                                                  add_172[0][0]
# __________________________________________________________________________________________________
# conv1d_346 (Conv1D)             (None, 2048, 64)     32832       add_173[0][0]
# __________________________________________________________________________________________________
# activation_342 (Activation)     (None, 2048, 64)     0           conv1d_346[0][0]
# __________________________________________________________________________________________________
# activation_343 (Activation)     (None, 2048, 64)     0           conv1d_346[0][0]
# __________________________________________________________________________________________________
# multiply_168 (Multiply)         (None, 2048, 64)     0           activation_342[0][0]
#                                                                  activation_343[0][0]
# __________________________________________________________________________________________________
# conv1d_347 (Conv1D)             (None, 2048, 1)      65          multiply_168[0][0]
# __________________________________________________________________________________________________
# add_174 (Add)                   (None, 2048, 256)    0           conv1d_347[0][0]
#                                                                  add_173[0][0]
# __________________________________________________________________________________________________
# conv1d_348 (Conv1D)             (None, 2048, 64)     32832       add_174[0][0]
# __________________________________________________________________________________________________
# activation_344 (Activation)     (None, 2048, 64)     0           conv1d_348[0][0]
# __________________________________________________________________________________________________
# activation_345 (Activation)     (None, 2048, 64)     0           conv1d_348[0][0]
# __________________________________________________________________________________________________
# multiply_169 (Multiply)         (None, 2048, 64)     0           activation_344[0][0]
#                                                                  activation_345[0][0]
# __________________________________________________________________________________________________
# conv1d_349 (Conv1D)             (None, 2048, 1)      65          multiply_169[0][0]
# __________________________________________________________________________________________________
# add_175 (Add)                   (None, 2048, 256)    0           conv1d_349[0][0]
#                                                                  add_174[0][0]
# __________________________________________________________________________________________________
# conv1d_350 (Conv1D)             (None, 2048, 64)     32832       add_175[0][0]
# __________________________________________________________________________________________________
# activation_346 (Activation)     (None, 2048, 64)     0           conv1d_350[0][0]
# __________________________________________________________________________________________________
# activation_347 (Activation)     (None, 2048, 64)     0           conv1d_350[0][0]
# __________________________________________________________________________________________________
# multiply_170 (Multiply)         (None, 2048, 64)     0           activation_346[0][0]
#                                                                  activation_347[0][0]
# __________________________________________________________________________________________________
# conv1d_351 (Conv1D)             (None, 2048, 1)      65          multiply_170[0][0]
# __________________________________________________________________________________________________
# add_176 (Add)                   (None, 2048, 256)    0           conv1d_351[0][0]
#                                                                  add_175[0][0]
# __________________________________________________________________________________________________
# conv1d_352 (Conv1D)             (None, 2048, 64)     32832       add_176[0][0]
# __________________________________________________________________________________________________
# activation_348 (Activation)     (None, 2048, 64)     0           conv1d_352[0][0]
# __________________________________________________________________________________________________
# activation_349 (Activation)     (None, 2048, 64)     0           conv1d_352[0][0]
# __________________________________________________________________________________________________
# multiply_171 (Multiply)         (None, 2048, 64)     0           activation_348[0][0]
#                                                                  activation_349[0][0]
# __________________________________________________________________________________________________
# conv1d_353 (Conv1D)             (None, 2048, 1)      65          multiply_171[0][0]
# __________________________________________________________________________________________________
# add_177 (Add)                   (None, 2048, 256)    0           conv1d_353[0][0]
#                                                                  add_176[0][0]
# __________________________________________________________________________________________________
# conv1d_354 (Conv1D)             (None, 2048, 64)     32832       add_177[0][0]
# __________________________________________________________________________________________________
# activation_350 (Activation)     (None, 2048, 64)     0           conv1d_354[0][0]
# __________________________________________________________________________________________________
# activation_351 (Activation)     (None, 2048, 64)     0           conv1d_354[0][0]
# __________________________________________________________________________________________________
# multiply_172 (Multiply)         (None, 2048, 64)     0           activation_350[0][0]
#                                                                  activation_351[0][0]
# __________________________________________________________________________________________________
# conv1d_355 (Conv1D)             (None, 2048, 1)      65          multiply_172[0][0]
# __________________________________________________________________________________________________
# add_178 (Add)                   (None, 2048, 256)    0           conv1d_355[0][0]
#                                                                  add_177[0][0]
# __________________________________________________________________________________________________
# conv1d_356 (Conv1D)             (None, 2048, 64)     32832       add_178[0][0]
# __________________________________________________________________________________________________
# activation_352 (Activation)     (None, 2048, 64)     0           conv1d_356[0][0]
# __________________________________________________________________________________________________
# activation_353 (Activation)     (None, 2048, 64)     0           conv1d_356[0][0]
# __________________________________________________________________________________________________
# multiply_173 (Multiply)         (None, 2048, 64)     0           activation_352[0][0]
#                                                                  activation_353[0][0]
# __________________________________________________________________________________________________
# conv1d_357 (Conv1D)             (None, 2048, 1)      65          multiply_173[0][0]
# __________________________________________________________________________________________________
# add_179 (Add)                   (None, 2048, 256)    0           conv1d_357[0][0]
#                                                                  add_178[0][0]
# __________________________________________________________________________________________________
# conv1d_358 (Conv1D)             (None, 2048, 64)     32832       add_179[0][0]
# __________________________________________________________________________________________________
# activation_354 (Activation)     (None, 2048, 64)     0           conv1d_358[0][0]
# __________________________________________________________________________________________________
# activation_355 (Activation)     (None, 2048, 64)     0           conv1d_358[0][0]
# __________________________________________________________________________________________________
# multiply_174 (Multiply)         (None, 2048, 64)     0           activation_354[0][0]
#                                                                  activation_355[0][0]
# __________________________________________________________________________________________________
# conv1d_359 (Conv1D)             (None, 2048, 1)      65          multiply_174[0][0]
# __________________________________________________________________________________________________
# add_180 (Add)                   (None, 2048, 256)    0           conv1d_359[0][0]
#                                                                  add_179[0][0]
# __________________________________________________________________________________________________
# conv1d_360 (Conv1D)             (None, 2048, 64)     32832       add_180[0][0]
# __________________________________________________________________________________________________
# activation_356 (Activation)     (None, 2048, 64)     0           conv1d_360[0][0]
# __________________________________________________________________________________________________
# activation_357 (Activation)     (None, 2048, 64)     0           conv1d_360[0][0]
# __________________________________________________________________________________________________
# multiply_175 (Multiply)         (None, 2048, 64)     0           activation_356[0][0]
#                                                                  activation_357[0][0]
# __________________________________________________________________________________________________
# conv1d_361 (Conv1D)             (None, 2048, 1)      65          multiply_175[0][0]
# __________________________________________________________________________________________________
# add_181 (Add)                   (None, 2048, 256)    0           conv1d_361[0][0]
#                                                                  add_180[0][0]
# __________________________________________________________________________________________________
# conv1d_362 (Conv1D)             (None, 2048, 64)     32832       add_181[0][0]
# __________________________________________________________________________________________________
# activation_358 (Activation)     (None, 2048, 64)     0           conv1d_362[0][0]
# __________________________________________________________________________________________________
# activation_359 (Activation)     (None, 2048, 64)     0           conv1d_362[0][0]
# __________________________________________________________________________________________________
# multiply_176 (Multiply)         (None, 2048, 64)     0           activation_358[0][0]
#                                                                  activation_359[0][0]
# __________________________________________________________________________________________________
# conv1d_363 (Conv1D)             (None, 2048, 1)      65          multiply_176[0][0]
# __________________________________________________________________________________________________
# add_182 (Add)                   (None, 2048, 256)    0           conv1d_363[0][0]
#                                                                  add_181[0][0]
# __________________________________________________________________________________________________
# conv1d_364 (Conv1D)             (None, 2048, 64)     32832       add_182[0][0]
# __________________________________________________________________________________________________
# activation_360 (Activation)     (None, 2048, 64)     0           conv1d_364[0][0]
# __________________________________________________________________________________________________
# activation_361 (Activation)     (None, 2048, 64)     0           conv1d_364[0][0]
# __________________________________________________________________________________________________
# multiply_177 (Multiply)         (None, 2048, 64)     0           activation_360[0][0]
#                                                                  activation_361[0][0]
# __________________________________________________________________________________________________
# conv1d_365 (Conv1D)             (None, 2048, 1)      65          multiply_177[0][0]
# __________________________________________________________________________________________________
# add_183 (Add)                   (None, 2048, 256)    0           conv1d_365[0][0]
#                                                                  add_182[0][0]
# __________________________________________________________________________________________________
# conv1d_366 (Conv1D)             (None, 2048, 64)     32832       add_183[0][0]
# __________________________________________________________________________________________________
# activation_362 (Activation)     (None, 2048, 64)     0           conv1d_366[0][0]
# __________________________________________________________________________________________________
# activation_363 (Activation)     (None, 2048, 64)     0           conv1d_366[0][0]
# __________________________________________________________________________________________________
# multiply_178 (Multiply)         (None, 2048, 64)     0           activation_362[0][0]
#                                                                  activation_363[0][0]
# __________________________________________________________________________________________________
# conv1d_367 (Conv1D)             (None, 2048, 1)      65          multiply_178[0][0]
# __________________________________________________________________________________________________
# add_184 (Add)                   (None, 2048, 256)    0           conv1d_367[0][0]
#                                                                  add_183[0][0]
# __________________________________________________________________________________________________
# conv1d_368 (Conv1D)             (None, 2048, 64)     32832       add_184[0][0]
# __________________________________________________________________________________________________
# activation_364 (Activation)     (None, 2048, 64)     0           conv1d_368[0][0]
# __________________________________________________________________________________________________
# activation_365 (Activation)     (None, 2048, 64)     0           conv1d_368[0][0]
# __________________________________________________________________________________________________
# multiply_179 (Multiply)         (None, 2048, 64)     0           activation_364[0][0]
#                                                                  activation_365[0][0]
# __________________________________________________________________________________________________
# conv1d_369 (Conv1D)             (None, 2048, 1)      65          multiply_179[0][0]
# __________________________________________________________________________________________________
# add_186 (Add)                   (None, 2048, 1)      0           conv1d_311[0][0]
#                                                                  conv1d_313[0][0]
#                                                                  conv1d_315[0][0]
#                                                                  conv1d_317[0][0]
#                                                                  conv1d_319[0][0]
#                                                                  conv1d_321[0][0]
#                                                                  conv1d_323[0][0]
#                                                                  conv1d_325[0][0]
#                                                                  conv1d_327[0][0]
#                                                                  conv1d_329[0][0]
#                                                                  conv1d_331[0][0]
#                                                                  conv1d_333[0][0]
#                                                                  conv1d_335[0][0]
#                                                                  conv1d_337[0][0]
#                                                                  conv1d_339[0][0]
#                                                                  conv1d_341[0][0]
#                                                                  conv1d_343[0][0]
#                                                                  conv1d_345[0][0]
#                                                                  conv1d_347[0][0]
#                                                                  conv1d_349[0][0]
#                                                                  conv1d_351[0][0]
#                                                                  conv1d_353[0][0]
#                                                                  conv1d_355[0][0]
#                                                                  conv1d_357[0][0]
#                                                                  conv1d_359[0][0]
#                                                                  conv1d_361[0][0]
#                                                                  conv1d_363[0][0]
#                                                                  conv1d_365[0][0]
#                                                                  conv1d_367[0][0]
#                                                                  conv1d_369[0][0]
# __________________________________________________________________________________________________
# activation_366 (Activation)     (None, 2048, 1)      0           add_186[0][0]
# __________________________________________________________________________________________________
# conv1d_370 (Conv1D)             (None, 2048, 2048)   8192        activation_366[0][0]
# __________________________________________________________________________________________________
# conv1d_371 (Conv1D)             (None, 2048, 256)    1573120     conv1d_370[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2048, 256)    65792       conv1d_371[0][0]
# ==================================================================================================
# Total params: 2,634,014
# Trainable params: 2,634,014
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Here we instantiate the DataGenerators and start the training.
training_gen=MyDatagen(range(46400))
val_gen=MyDatagen(range(11600), validation=True)

model.fit(x=training_gen, validation_data=val_gen, epochs=100)
# Out:
# Epoch 1/100
# 2900/2900 [==============================] - 704s 243ms/step - loss: 4.8341 - accuracy: 0.0247 - val_loss: 4.8005 - val_accuracy: 0.0268
# Epoch 2/100
# 2900/2900 [==============================] - 702s 242ms/step - loss: 4.7572 - accuracy: 0.0282 - val_loss: 4.7900 - val_accuracy: 0.0271
# Epoch 3/100
# 2900/2900 [==============================] - 702s 242ms/step - loss: 4.7451 - accuracy: 0.0288 - val_loss: 4.7861 - val_accuracy: 0.0288
# Epoch 4/100
# 2900/2900 [==============================] - 701s 242ms/step - loss: 4.7404 - accuracy: 0.0291 - val_loss: 4.7690 - val_accuracy: 0.0288
# Epoch 5/100
# 2900/2900 [==============================] - 700s 241ms/step - loss: 4.7350 - accuracy: 0.0293 - val_loss: 4.7772 - val_accuracy: 0.0285
# Epoch 6/100
# 2900/2900 [==============================] - 700s 241ms/step - loss: 4.7261 - accuracy: 0.0296 - val_loss: 4.7541 - val_accuracy: 0.0283
# Epoch 7/100
# 2900/2900 [==============================] - 700s 241ms/step - loss: 4.7139 - accuracy: 0.0300 - val_loss: 4.7488 - val_accuracy: 0.0291
# Epoch 8/100
# 2900/2900 [==============================] - 700s 241ms/step - loss: 4.7090 - accuracy: 0.0303 - val_loss: 4.7464 - val_accuracy: 0.0297
# Epoch 9/100
# 2900/2900 [==============================] - 700s 241ms/step - loss: 4.7049 - accuracy: 0.0305 - val_loss: 4.7427 - val_accuracy: 0.0296
# Epoch 10/100
# 2900/2900 [==============================] - 699s 241ms/step - loss: 4.7017 - accuracy: 0.0305 - val_loss: 4.7446 - val_accuracy: 0.0299
# Epoch 11/100
# 2900/2900 [==============================] - 699s 241ms/step - loss: 4.6999 - accuracy: 0.0307 - val_loss: 4.7392 - val_accuracy: 0.0298
# Epoch 12/100
# 2900/2900 [==============================] - 700s 241ms/step - loss: 4.6965 - accuracy: 0.0308 - val_loss: 4.7269 - val_accuracy: 0.0306
# Epoch 13/100
# 2900/2900 [==============================] - 699s 241ms/step - loss: 4.6958 - accuracy: 0.0309 - val_loss: 4.7278 - val_accuracy: 0.0301
# Epoch 14/100
# 2900/2900 [==============================] - 699s 241ms/step - loss: 4.6933 - accuracy: 0.0309 - val_loss: 4.7243 - val_accuracy: 0.0305
# Epoch 15/100
# 2900/2900 [==============================] - 699s 241ms/step - loss: 4.6921 - accuracy: 0.0309 - val_loss: 4.7283 - val_accuracy: 0.0304
# Epoch 16/100
#  196/2900 [=>............................] - ETA: 9:41 - loss: 4.6896 - accuracy: 0.0302
